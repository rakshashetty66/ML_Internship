# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\raksh\Downloads\ObesityDataSet_raw_and_data_sinthetic.csv")

# %%
df
# Out:
#       Age  Height  Weight family_history_with_overweight FAVC  FCVC  NCP  \
# 0      21    1.62   64.00                            yes   no   2.0  3.0
# 1      21    1.52   56.00                            yes   no   3.0  3.0
# 2      23    1.80   77.00                            yes   no   2.0  3.0
# 3      27    1.80   87.00                             no   no   3.0  3.0
# 4      22    1.78   89.80                             no   no   2.0  1.0
# ...   ...     ...     ...                            ...  ...   ...  ...
# 2106   21    1.71  131.41                            yes  yes   3.0  3.0
# 2107   22    1.75  133.74                            yes  yes   3.0  3.0
# 2108   23    1.75  133.69                            yes  yes   3.0  3.0
# 2109   24    1.74  133.35                            yes  yes   3.0  3.0
# 2110   24    1.74  133.47                            yes  yes   3.0  3.0
#
#       CH2O   FAF    TUE        CALC  Gender_Male
# 0     2.00  0.00  1.000          no          0.0
# 1     3.00  3.00  0.000   Sometimes          0.0
# 2     2.00  2.00  1.000  Frequently          1.0
# 3     2.00  2.00  0.000  Frequently          1.0
# 4     2.00  0.00  0.000   Sometimes          1.0
# ...    ...   ...    ...         ...          ...
# 2106  1.73  1.68  0.906   Sometimes          0.0
# 2107  2.01  1.34  0.599   Sometimes          0.0
# 2108  2.05  1.41  0.646   Sometimes          0.0
# 2109  2.85  1.14  0.586   Sometimes          0.0
# 2110  2.86  1.03  0.714   Sometimes          0.0
#
# [2111 rows x 12 columns]

# %%
df.head()
# Out:
#    Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  NCP  \
# 0  Female   21    1.62    64.0                            yes   no   2.0  3.0
# 1  Female   21    1.52    56.0                            yes   no   3.0  3.0
# 2    Male   23    1.80    77.0                            yes   no   2.0  3.0
# 3    Male   27    1.80    87.0                             no   no   3.0  3.0
# 4    Male   22    1.78    89.8                             no   no   2.0  1.0
#
#         CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0  Sometimes    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  Sometimes    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3  Sometimes    no   2.0   no  2.0  0.0  Frequently                Walking
# 4  Sometimes    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#             NObeyesdad
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# 4  Overweight_Level_II

# %%
df.tail()
# Out:
#       Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 2106  Female   21    1.71  131.41                            yes  yes   3.0
# 2107  Female   22    1.75  133.74                            yes  yes   3.0
# 2108  Female   23    1.75  133.69                            yes  yes   3.0
# 2109  Female   24    1.74  133.35                            yes  yes   3.0
# 2110  Female   24    1.74  133.47                            yes  yes   3.0
#
#       NCP       CAEC SMOKE  CH2O SCC   FAF    TUE       CALC  \
# 2106  3.0  Sometimes    no  1.73  no  1.68  0.906  Sometimes
# 2107  3.0  Sometimes    no  2.01  no  1.34  0.599  Sometimes
# 2108  3.0  Sometimes    no  2.05  no  1.41  0.646  Sometimes
# 2109  3.0  Sometimes    no  2.85  no  1.14  0.586  Sometimes
# 2110  3.0  Sometimes    no  2.86  no  1.03  0.714  Sometimes
#
#                      MTRANS        NObeyesdad
# 2106  Public_Transportation  Obesity_Type_III
# 2107  Public_Transportation  Obesity_Type_III
# 2108  Public_Transportation  Obesity_Type_III
# 2109  Public_Transportation  Obesity_Type_III
# 2110  Public_Transportation  Obesity_Type_III

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   int64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
#  12  FAF                             2111 non-null   float64
#  13  TUE                             2111 non-null   float64
#  14  CALC                            2111 non-null   object
#  15  MTRANS                          2111 non-null   object
#  16  NObeyesdad                      2111 non-null   object
# dtypes: float64(7), int64(1), object(9)
# memory usage: 280.5+ KB

# %%
df.isna().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
df.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.315964     1.701620    86.586035     2.418986     2.685651
# std       6.357078     0.093368    26.191163     0.533996     0.778079
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      20.000000     1.630000    65.470000     2.000000     2.660000
# 50%      23.000000     1.700000    83.000000     2.390000     3.000000
# 75%      26.000000     1.770000   107.430000     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008053     1.010313     0.657861
# std       0.612950     0.850613     0.608926
# min       1.000000     0.000000     0.000000
# 25%       1.585000     0.125000     0.000000
# 50%       2.000000     1.000000     0.625000
# 75%       2.480000     1.670000     1.000000
# max       3.000000     3.000000     2.000000

# %%
import matplotlib.pyplot as plt

df['Age'].hist(bins=20, color='lightblue', edgecolor='black')

plt.title("Age Distribution of Passengers")
plt.xlabel("Age")
plt.ylabel("Frequency")

plt.show()

# %%
import matplotlib.pyplot as plt
df['Height'].hist(bins=20,color='pink',edgecolor='black')
plt.title("The height vs The frequency")
plt.xlabel('Height')
plt.ylabel("Frequency")
plt.show()

# %%
import matplotlib.pyplot as plt

df['Weight'].hist(bins=20, color='lightgray', edgecolor='black')
plt.title("The Weight vs The Frequency")
plt.xlabel('Weight')
plt.ylabel("Frequency")
plt.show()

# %%
df
# Out:
#       Age  Height  Weight family_history_with_overweight FAVC  FCVC  NCP  \
# 0      21    1.62   64.00                            yes   no   2.0  3.0
# 1      21    1.52   56.00                            yes   no   3.0  3.0
# 2      23    1.80   77.00                            yes   no   2.0  3.0
# 3      27    1.80   87.00                             no   no   3.0  3.0
# 4      22    1.78   89.80                             no   no   2.0  1.0
# ...   ...     ...     ...                            ...  ...   ...  ...
# 2106   21    1.71  131.41                            yes  yes   3.0  3.0
# 2107   22    1.75  133.74                            yes  yes   3.0  3.0
# 2108   23    1.75  133.69                            yes  yes   3.0  3.0
# 2109   24    1.74  133.35                            yes  yes   3.0  3.0
# 2110   24    1.74  133.47                            yes  yes   3.0  3.0
#
#       CH2O   FAF    TUE        CALC  Gender_Male
# 0     2.00  0.00  1.000          no          0.0
# 1     3.00  3.00  0.000   Sometimes          0.0
# 2     2.00  2.00  1.000  Frequently          1.0
# 3     2.00  2.00  0.000  Frequently          1.0
# 4     2.00  0.00  0.000   Sometimes          1.0
# ...    ...   ...    ...         ...          ...
# 2106  1.73  1.68  0.906   Sometimes          0.0
# 2107  2.01  1.34  0.599   Sometimes          0.0
# 2108  2.05  1.41  0.646   Sometimes          0.0
# 2109  2.85  1.14  0.586   Sometimes          0.0
# 2110  2.86  1.03  0.714   Sometimes          0.0
#
# [2111 rows x 12 columns]

# %%
import matplotlib.pyplot as plt
gen=df[df['Age']>30][['Weight','Height']]
x=gen['Weight']
y=gen['Height']
plt.figure(figsize=(8,6),dpi=60)
plt.title("Weight vs Height")
plt.xlabel("Weight of a person")
plt.ylabel("Height of a person")
plt.scatter(x,y, color='lightcoral')

# %%
import matplotlib.pyplot as plt
gen=df[df['Age']>30][['Weight','Height']]
x=gen['Weight']
y=gen['Height']
plt.figure(figsize=(8,6),dpi=60)
plt.title("Weight vs Height")
plt.xlabel("Weight of a person")
plt.ylabel("Height of a person")
plt.plot(x,y)

# %%
df
# Out:
#       Age  Height  Weight family_history_with_overweight FAVC  FCVC  NCP  \
# 0      21    1.62   64.00                            yes   no   2.0  3.0
# 1      21    1.52   56.00                            yes   no   3.0  3.0
# 2      23    1.80   77.00                            yes   no   2.0  3.0
# 3      27    1.80   87.00                             no   no   3.0  3.0
# 4      22    1.78   89.80                             no   no   2.0  1.0
# ...   ...     ...     ...                            ...  ...   ...  ...
# 2106   21    1.71  131.41                            yes  yes   3.0  3.0
# 2107   22    1.75  133.74                            yes  yes   3.0  3.0
# 2108   23    1.75  133.69                            yes  yes   3.0  3.0
# 2109   24    1.74  133.35                            yes  yes   3.0  3.0
# 2110   24    1.74  133.47                            yes  yes   3.0  3.0
#
#       CH2O   FAF    TUE        CALC  Gender_Male
# 0     2.00  0.00  1.000          no          0.0
# 1     3.00  3.00  0.000   Sometimes          0.0
# 2     2.00  2.00  1.000  Frequently          1.0
# 3     2.00  2.00  0.000  Frequently          1.0
# 4     2.00  0.00  0.000   Sometimes          1.0
# ...    ...   ...    ...         ...          ...
# 2106  1.73  1.68  0.906   Sometimes          0.0
# 2107  2.01  1.34  0.599   Sometimes          0.0
# 2108  2.05  1.41  0.646   Sometimes          0.0
# 2109  2.85  1.14  0.586   Sometimes          0.0
# 2110  2.86  1.03  0.714   Sometimes          0.0
#
# [2111 rows x 12 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load your dataset
df = pd.read_csv(r"C:\Users\raksh\Downloads\ObesityDataSet_raw_and_data_sinthetic.csv")  # Change to your actual file path

# Clean column names (strip spaces)
df.columns = df.columns.str.strip()

# Convert 'SMOKE' column values to lowercase
df['SMOKE'] = df['SMOKE'].astype(str).str.lower()

# Filter data where smoking status is 'yes'
if 'SMOKE' in df.columns and 'Gender' in df.columns:
    gen = df[df['SMOKE'] == 'yes']['Gender'].map(lambda x: 'Male' if x == 'Male' else 'Female')

    # Count occurrences
    heart = gen.value_counts()

    # Plot the bar chart
    plt.figure(figsize=(8, 6), dpi=60)
    plt.bar(heart.index, heart.values, color='peachpuff')
    plt.title("Gender Distribution of Smokers")
    plt.xlabel('Gender')
    plt.ylabel('Counts')
    plt.show()
else:
    print("❌ Column 'SMOKE' or 'Gender' not found in the dataframe.")

# %%
import matplotlib.pyplot as plt

# Count occurrences of family history and FAVC within Obesity Type III
heart_counts = df[df['NObeyesdad'] == 'Obesity_Type_III'][['family_history_with_overweight', 'FAVC']].apply(pd.Series.value_counts)

# Summing occurrences across both categories
heart_summed = heart_counts.sum(axis=1)  # Sum counts across columns

# Extracting labels and values
labels = heart_summed.index  # Categories
sizes = heart_summed.values  # Corresponding counts

# Plotting the pie chart
plt.figure(figsize=(8,6), dpi=100)
plt.pie(sizes, labels=labels, colors=['orange', 'lightblue', 'pink'], autopct='%1.1f%%')
plt.legend(labels)
plt.title("Distribution of Family History & FAVC in Obesity Type III")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   int64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
#  12  FAF                             2111 non-null   float64
#  13  TUE                             2111 non-null   float64
#  14  CALC                            2111 non-null   object
#  15  MTRANS                          2111 non-null   object
#  16  NObeyesdad                      2111 non-null   object
# dtypes: float64(7), int64(1), object(9)
# memory usage: 280.5+ KB

# %%
columns_to_drop = ['NObeyesdad', 'MTRANS', 'SCC', 'SMOKE', 'CAEC']

# Drop only if they exist
df = df.drop(columns=[col for col in columns_to_drop if col in df.columns])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   int64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CH2O                            2111 non-null   float64
#  9   FAF                             2111 non-null   float64
#  10  TUE                             2111 non-null   float64
#  11  CALC                            2111 non-null   object
# dtypes: float64(7), int64(1), object(4)
# memory usage: 198.0+ KB

# %%
# df['Gender'].unique()

# %%
# df['Gender']=df['Gender'].map({'Female':0,'Male':1,'Other':2})

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

# Initialize OneHotEncoder with updated argument
encoder = OneHotEncoder(drop='first', sparse_output=False)  # Updated argument name

# Fit and transform the 'Gender' column
encoded_array = encoder.fit_transform(df[['Gender']])

# Convert to DataFrame
encoded_df = pd.DataFrame(encoded_array, columns=encoder.get_feature_names_out(['Gender']))

# Drop original 'Gender' column and merge the encoded data
df = df.drop(columns=['Gender']).reset_index(drop=True)
df = pd.concat([df, encoded_df], axis=1)

# Display the updated DataFrame
print(df.head())
# Out:
#    Age  Height  Weight family_history_with_overweight FAVC  FCVC  NCP  CH2O  \
# 0   21    1.62    64.0                            yes   no   2.0  3.0   2.0
# 1   21    1.52    56.0                            yes   no   3.0  3.0   3.0
# 2   23    1.80    77.0                            yes   no   2.0  3.0   2.0
# 3   27    1.80    87.0                             no   no   3.0  3.0   2.0
# 4   22    1.78    89.8                             no   no   2.0  1.0   2.0
#
#    FAF  TUE        CALC  Gender_Male
# 0  0.0  1.0          no          0.0
# 1  3.0  0.0   Sometimes          0.0
# 2  2.0  1.0  Frequently          1.0
# 3  2.0  0.0  Frequently          1.0
# 4  0.0  0.0   Sometimes          1.0

# %%
# df=pd.get_dummies(df,columns=['family_history_with_overweight'],dtype=int)
# df

# %%
# df.info()

# %%
# df['FAVC'].unique()

# %%
# df['FAVC']=df['FAVC'].map({'no':0,'yes':1})

# %%
# #step1:import
# from sklearn.preprocessing import LabelEncoder
# #step2:Create object for class
# lb=LabelEncoder()
# #step3:Pass the data totransform here if thereare multiple columns if you are considering then you have to create different label objects
# df['CALC']=lb.fit_transform(df['CALC'])
# df
