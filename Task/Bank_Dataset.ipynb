# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\raksh\Downloads\Bank\bank.csv")

# %% [markdown]
# #### Printing first 6 Rows

# %%
df.head(6)
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
# 5   42  management   single   tertiary      no        0     yes  yes  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes
# ...

# %% [markdown]
# #### Printing last 4 Rows

# %%
df.tail(4)
# Out:
#        age         job  marital  education default  balance housing loan  \
# 11158   39    services  married  secondary      no      733      no   no
# 11159   32  technician   single  secondary      no       29      no   no
# 11160   43  technician  married  secondary      no        0      no  yes
# 11161   34  technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 11158   unknown   16   jun        83         4     -1         0  unknown
# 11159  cellular   19   aug       156         2     -1         0  unknown
# 11160  cellular    8   may         9         2    172         5  failure
# 11161  cellular    9   jul       628         1     -1         0  unknown
#
#       deposit
# 11158      no
# 11159      no
# 11160      no
# 11161      no

# %% [markdown]
# #### Printing 5 Sample Rows

# %%
df.sample(5)
# Out:
#        age          job  marital  education default  balance housing loan  \
# 3557    29   unemployed   single   tertiary      no       70      no   no
# 8716    31   management   single   tertiary      no     5691     yes   no
# 5959    47       admin.   single  secondary      no     3957     yes   no
# 6546    40     services  married  secondary      no        0     yes  yes
# 10349   60  blue-collar  married    primary      no      228     yes   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome  \
# 3557    cellular   25   may       393         1     -1         0  unknown
# 8716    cellular   21   nov        37         2    123         1  failure
# 5959   telephone   11   may        58         3    334         3    other
# 6546    cellular    2   feb       226         2     -1         0  unknown
# 10349    unknown   28   may       249        11     -1         0  unknown
#
#       deposit
# 3557      yes
# 8716       no
# 5959       no
# ...

# %% [markdown]
# #### To get Statistical summary of df

# %%
df.describe()
# Out:
#                 age       balance           day      duration      campaign  \
# count  11162.000000  11162.000000  11162.000000  11162.000000  11162.000000
# mean      41.231948   1528.538524     15.658036    371.993818      2.508421
# std       11.913369   3225.413326      8.420740    347.128386      2.722077
# min       18.000000  -6847.000000      1.000000      2.000000      1.000000
# 25%       32.000000    122.000000      8.000000    138.000000      1.000000
# 50%       39.000000    550.000000     15.000000    255.000000      2.000000
# 75%       49.000000   1708.000000     22.000000    496.000000      3.000000
# max       95.000000  81204.000000     31.000000   3881.000000     63.000000
#
#               pdays      previous
# count  11162.000000  11162.000000
# mean      51.330407      0.832557
# std      108.758282      2.292007
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       20.750000      1.000000
# ...

# %% [markdown]
# #### To Check Information about dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11162 non-null  int64
#  1   job        11162 non-null  object
#  2   marital    11162 non-null  object
#  3   education  11162 non-null  object
#  4   default    11162 non-null  object
#  5   balance    11162 non-null  int64
#  6   housing    11162 non-null  object
#  7   loan       11162 non-null  object
#  8   contact    11162 non-null  object
#  9   day        11162 non-null  int64
#  10  month      11162 non-null  object
#  11  duration   11162 non-null  int64
#  12  campaign   11162 non-null  int64
#  13  pdays      11162 non-null  int64
#  14  previous   11162 non-null  int64
#  15  poutcome   11162 non-null  object
#  16  deposit    11162 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 1.4+ MB

# %% [markdown]
# #### To retrieve single column

# %%
df['housing']
# Out:
# 0        yes
# 1         no
# 2        yes
# 3        yes
# 4         no
#         ...
# 11157    yes
# 11158     no
# 11159     no
# 11160     no
# 11161     no
# Name: housing, Length: 11162, dtype: object

# %% [markdown]
# #### To retrieve multiple column

# %%
df[['contact','duration','previous']]
# Out:
#         contact  duration  previous
# 0       unknown      1042         0
# 1       unknown      1467         0
# 2       unknown      1389         0
# 3       unknown       579         0
# 4       unknown       673         0
# ...         ...       ...       ...
# 11157  cellular       257         0
# 11158   unknown        83         0
# 11159  cellular       156         0
# 11160  cellular         9         5
# 11161  cellular       628         0
#
# [11162 rows x 3 columns]

# %% [markdown]
# #### To check type of df

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### To return only columns

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'deposit'],
#       dtype='object')

# %% [markdown]
# #### To check datatype of each coulmns

# %%
df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# deposit      object
# dtype: object

# %% [markdown]
# #### To check shape of dataframe

# %%
df.shape
# Out:
# (11162, 17)

# %%
#### To create a new column

# %%
df['Previous']=df['previous']*2
df
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %% [markdown]
# #### To create a new column with our own value

# %%
df['status']=0
df
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %% [markdown]
# #### Unique values

# %%
# Instead of manually typing we can also do 

col = df.columns
for i in col:
    print("Column: ",i)
    print("Unique Values")
    print(df[i].unique())
    print("--------------")
# Out:
# Column:  age
# Unique Values
# [59 56 41 55 54 42 60 37 28 38 30 29 46 31 35 32 49 43 26 40 33 23 48 45
#  36 52 53 39 57 51 44 24 50 27 34 47 25 58 61 68 75 22 69 66 85 72 90 67
#  71 21 74 65 62 83 70 76 77 19 73 63 20 78 95 64 79 82 18 86 84 87 92 81
#  80 93 88 89]
# --------------
# Column:  job
# Unique Values
# ['admin.' 'technician' 'services' 'management' 'retired' 'blue-collar'
#  'unemployed' 'entrepreneur' 'housemaid' 'unknown' 'self-employed'
#  'student']
# --------------
# Column:  marital
# Unique Values
# ['married' 'single' 'divorced']
# --------------
# Column:  education
# Unique Values
# ['secondary' 'tertiary' 'primary' 'unknown']
# --------------
# Column:  default
# Unique Values
# ['no' 'yes']
# --------------
# Column:  balance
# Unique Values
# [2343   45 1270 ... 1594 2593 -134]
# --------------
# Column:  housing
# Unique Values
# ['yes' 'no']
# --------------
# Column:  loan
# Unique Values
# ['no' 'yes']
# --------------
# Column:  contact
# ...

# %% [markdown]
# ## Parse the datframe or series using specific condition

# %% [markdown]
# #### 1. Display the rows that have duration greater than 200

# %%
df[df['duration']>200]
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11152   34    housemaid  married  secondary      no      390     yes   no
# 11153   43       admin.   single  secondary      no       35      no   no
# 11156   34  blue-collar   single  secondary      no      -72     yes   no
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11161   34   technician  married  secondary      no        0      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %% [markdown]
# #### 2. Retrieve the dataframe where campaign is 1

# %%
df[df['campaign']==1]
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 6       56   management  married   tertiary      no      830     yes  yes
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11151   40   management  married   tertiary      no      917     yes   no
# 11153   43       admin.   single  secondary      no       35      no   no
# 11154   52   technician  married   tertiary      no      523     yes  yes
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11161   34   technician  married  secondary      no        0      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %% [markdown]
# #### 3. Retrieve the dataframe where day is >=5

# %%
df[df['day']>=5]
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %% [markdown]
# #### 4. Return job, contact, month where deposit is yes

# %%
df[df['deposit']=="yes"][['job','contact','month']]
# Out:
#                job   contact month
# 0           admin.   unknown   may
# 1           admin.   unknown   may
# 2       technician   unknown   may
# 3         services   unknown   may
# 4           admin.   unknown   may
# ...            ...       ...   ...
# 5284       retired  cellular   apr
# 5285    management  cellular   oct
# 5286       retired  cellular   apr
# 5287  entrepreneur  cellular   jul
# 5288        admin.  cellular   jun
#
# [5289 rows x 3 columns]
